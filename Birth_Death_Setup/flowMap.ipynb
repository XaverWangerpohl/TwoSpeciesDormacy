# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors
from matplotlib.colors import ListedColormap, BoundaryNorm
import warnings
from tqdm import tqdm
import re
import random
import pickle
from pathlib import Path
from typing import Any, Union
import os
import scipy.sparse as sp
import scipy.sparse.linalg as spla
from tqdm import trange
from operator import itemgetter


# Example usage:
from functions import (
    compute_equilibrium,
    simulate_segment,
    plot_segment,
    run_invasion,
    global_invasability,
    local_invasibility,
    reconstruct_and_flow_map,
    flow_map
                       )                       


W_birth = 0.4
W_death = 0.1
Y_birth = 0.9
Y_death = 0.15

X_in = 0.1
X_out = 0.1
Z_in = 0.5
Z_out = 0.25

Time = 600.0
dt = 0.01

use_X = True
use_Z = False

num_points = 100
severity = 0.8
cycles = 5000
extinction_rate = 50
U_out = 0.21
U_in = 0.26
X_out = 0.26
X_in = 0.11

W,Y = compute_equilibrium(W_birth, W_death, Y_birth, Y_death)
W0 = W/2
X0 = W0 / (X_out / X_in)
V0 = W - W0
U0 = V0 / (U_out / U_in)
Y0 = Y
Z0 = Y0/ (Z_out /Z_in)
dt = 0.1

# %%
x = local_invasibility(
    V0, W0, Y0,
    W_birth, Y_birth, W_death, Y_death,
    Z_in, Z_out,
    extinction_rate, dt,
    use_X, use_Z,
    cycles, severity,
    grid_size=8,
    U_in_min  = 0.01,
    U_in_max  = 0.4, 
    U_out_min  = 0.01, 
    U_out_max  = 0.4,
    break_threshold=0.001,
    perturb_W=True,
    perturb_Y=False

)
# Out:
# Computing local invasibility: 100%|██████████| 6/6 [00:45<00:00,  7.62s/it]

# %%
preds = reconstruct_and_flow_map(
    x[3], x_vals=x[0], y_vals=x[1], folder='surface', arrow_scale=70, invert=True
)
# Out:
# Building Laplacian: 100%|██████████| 8/8 [00:00<00:00, 20984.64it/s]
# /Users/xaverwangerpohl/anaconda3/envs/dreiAcht/lib/python3.8/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Saved flow map with tested data points to surface/flow_map_tested_points.pdf

# %%
x = flow_map(
    V0, W0, Y0,
    W_birth, Y_birth, W_death, Y_death,
    Z_in, Z_out,
    extinction_rate, dt,
    use_X, use_Z,
    cycles, severity,
    grid_size=8,
    U_in_min  = 0.01,
    U_in_max  = 0.4, 
    U_out_min  = 0.01, 
    U_out_max  = 0.4,
    break_threshold=0.001,
    arrow_scale= 30

)
# Out:
# Computing local invasibility: 100%|██████████| 6/6 [00:12<00:00,  2.08s/it]
# Computing local invasibility:  33%|███▎      | 2/6 [00:42<01:25, 21.42s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x = flow_map(
#       2     V0, W0, Y0,
#       3     W_birth, Y_birth, W_death, Y_death,
#       4     Z_in, Z_out,
#       5     extinction_rate, dt,
#       6     use_X, use_Z,
#       7     cycles, severity,
#       8     grid_size=8,
#       9     U_in_min  = 0.01,
#      10     U_in_max  = 0.4,
#      11     U_out_min  = 0.01,
#      12     U_out_max  = 0.4,
#      13     break_threshold=0.001,
#      14     arrow_scale= 30
#      15
#      16 )
#
# File ~/Documents/GitHub/master-code/Birth_Death_Setup/functions.py:944, in flow_map(V0, W0, Y0, W_birth, Y_birth, W_death, Y_death, Z_in, Z_out, extinction_rate, dt, use_X, use_Z, cycles, severity, grid_size, U_in_min, U_in_max, U_out_min, U_out_max, folder, break_threshold, arrow_scale, figure_title)
#     927 U_in_vals, U_out_vals, _scoreY, deltasY, _ = local_invasibility(
#     928     V0, W0, Y0,
#     929     W_birth, Y_birth, W_death, Y_death,
#    (...)
#     940     perturb_Y=True,
#     941 )
#     943 # W extinction signs
# --> 944 _, _, _scoreW, deltasW, _ = local_invasibility(
#     945     V0, W0, Y0,
#     946     W_birth, Y_birth, W_death, Y_death,
#     947     Z_in, Z_out,
#     948     extinction_rate, dt,
#     949     use_X, use_Z,
#     950     cycles, severity,
#     951     grid_size=grid_size,
#     952     U_in_min=U_in_min, U_in_max=U_in_max,
#     953     U_out_min=U_out_min, U_out_max=U_out_max,
#     954     folder='local_invasibility',
#     955     break_threshold=break_threshold,
#     956     perturb_W=True,
#     957     perturb_Y=False,
#     958 )
#     960 title = figure_title or r'Flow Fields: $W^a$ vs $Y$ extinction'
#     961 pdf_path = flow_map_pair(
#     962     deltasW, deltasY,
#     963     U_in_vals, U_out_vals,
#    (...)
#     968     figure_title=title,
#     969 )
#
# File ~/Documents/GitHub/master-code/Birth_Death_Setup/functions.py:658, in local_invasibility(V0, W0, Y0, W_birth, Y_birth, W_death, Y_death, Z_in, Z_out, extinction_rate, dt, use_X, use_Z, cycles, severity, grid_size, U_in_min, U_in_max, U_out_min, U_out_max, folder, break_threshold, perturb_W, perturb_Y)
#     643 args = {
#     644 "V0": V0, "W0": W0, "Y0": Y0,
#     645 "W_birth": W_birth, "Y_birth": Y_birth,
#    (...)
#     654 "plot": False, "break_threshold": break_threshold
#     655 }
#     656 argsdict[((i,j), (i+di,j+dj))] = args
# --> 658 deltaW = run_invasion(**args
#     659 )
#     660 # save findings to deltas
#     661 if deltaW> 0: # W can invade V
#
# File ~/Documents/GitHub/master-code/Birth_Death_Setup/functions.py:387, in run_invasion(V0, W0, Y0, W_birth, Y_birth, W_death, Y_death, X_in, X_out, U_in, U_out, Z_in, Z_out, extinction_rate, dt, use_X, use_Z, severity, cycles, perturb_W, perturb_Y, plot, stop, break_threshold, show_Y)
#     382 Y_finals = []
#     384 for n in range(1, cycles+1):
#     385
#     386     # 1) simulate one segment
# --> 387     t, U, V, W, X, Y, Z, X_plot, Z_plot, U_plot = simulate_segment(
#     388         V0=V_current, W0=W_current, Y0=Y_current, X0=X_current, Z0=Z_current, U0=U_current,
#     389         W_birth=W_birth, Y_birth=Y_birth, W_death=W_death, Y_death=Y_death,
#     390         X_in=X_in, Z_in=Z_in, X_out=X_out, Z_out=Z_out, U_in=U_in, U_out=U_out,
#     391         duration=extinction_rate, dt=dt,
#     392         use_X=use_X, use_Z=use_Z,
#     393         tol=1e-7,
#     394         stop_at_eq=True
#     395     )
#     397     # 2) record final values of the segment
#     398     V_final = V[-1]
#
# File ~/Documents/GitHub/master-code/Birth_Death_Setup/functions.py:180, in simulate_segment(U0, V0, W0, X0, Y0, Z0, W_birth, Y_birth, W_death, Y_death, X_in, X_out, U_in, U_out, Z_in, Z_out, duration, dt, use_X, use_Z, tol, stop_at_eq)
#     178 # If stop_at_eq=True, check for equilibrium
#     179 if stop_at_eq:
# --> 180     cond = (abs(dV) < tol and abs(dW) < tol and abs(dY) < tol)
#     181     if use_X:
#     182         cond &= abs(dX) < tol
#
# KeyboardInterrupt:
